# %% [markdown]
# https://medium.com/analytics-vidhya/data-analysis-end-to-end-imdb-dataset-2b6d9976ebc2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_column', None)
pd.set_option('display.max_row', None)
movies = pd.read_csv('Movie+Assignment+Data.csv')

# %%
movies
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
movies.shape
# Out:
# (100, 62)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
movies.describe(include='all')
# Out:
#              Title   title_year        budget         Gross  \
# count          100   100.000000  1.000000e+02  1.000000e+02
# unique         100          NaN           NaN           NaN
# top     La La Land          NaN           NaN           NaN
# freq             1          NaN           NaN           NaN
# mean           NaN  2012.820000  7.838400e+07  1.468679e+08
# std            NaN     1.919491  7.445295e+07  1.454004e+08
# min            NaN  2010.000000  3.000000e+06  2.238380e+05
# 25%            NaN  2011.000000  1.575000e+07  4.199752e+07
# 50%            NaN  2013.000000  4.225000e+07  1.070266e+08
# 75%            NaN  2014.000000  1.500000e+08  2.107548e+08
# max            NaN  2016.000000  2.600000e+08  9.366622e+08
#
#              actor_1_name actor_2_name   actor_3_name  actor_1_facebook_likes  \
# count                 100          100            100              100.000000
# unique                 75           94             96                     NaN
# ...

# %%
movies['Gross']=movies['Gross'].floordiv(1000000)
movies['budget']=movies['budget'].floordiv(1000000)

# %%
movies.insert(4, column='profit',value= movies['Gross']-movies['budget'])

# %%
movies.sort_values(by=['profit'],ascending=False, inplace=True, ignore_index=True)

# %%
top_ten=movies.loc[0:9]
top_ten.head(10)
# Out:
#                                         Title  title_year  budget  Gross  \
# 0  Star Wars: Episode VII - The Force Awakens        2015     245    936
# 1                                The Avengers        2012     220    623
# 2                                    Deadpool        2016      58    363
# 3             The Hunger Games: Catching Fire        2013     130    424
# 4                                 Toy Story 3        2010     200    414
# 5                       The Dark Knight Rises        2012     250    448
# 6                              The Lego Movie        2014      60    257
# 7                                    Zootopia        2016     150    341
# 8                               Despicable Me        2010      69    251
# 9                                  Inside Out        2015     175    356
#
#    profit       actor_1_name       actor_2_name           actor_3_name  \
# 0     691        Doug Walker         Rob Walker                      0
# ...

# %%
sns.set_style("darkgrid")

plt.figure(figsize=[8,6])

h=sns.jointplot(x='budget', y='profit', data=movies, color='blue')
h.set_axis_labels('budget', 'profit', fontsize=12)
plt.subplots_adjust(top= 0.9)
plt.suptitle('Scatter plot of budget and profit', fontsize = 15)
plt.show()

# %%
negative_profit = movies[movies['profit'] < 0]

# %%
negative_profit
# Out:
#                           Title  title_year  budget  Gross  profit  \
# 89      Tucker and Dale vs Evil        2010       5      0      -5
# 90                        Amour        2012       8      0      -8
# 91                         Rush        2013      38     26     -12
# 92                      Warrior        2011      25     13     -12
# 93                      Flipped        2010      14      1     -13
# 94           X-Men: First Class        2011     160    146     -14
# 95  Scott Pilgrim vs. the World        2010      60     31     -29
# 96                      Tangled        2010     260    200     -60
# 97             Edge of Tomorrow        2014     178    100     -78
# 98            The Little Prince        2015      81      1     -80
# 99                         Hugo        2011     170     73     -97
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 89       Katrina Bowden        Tyler Labine          Chelan Simmons
# ...

# %%
negative_profit=negative_profit.reset_index(drop='True')

# %%
negative_profit.sort_values(by='profit')
# Out:
#                           Title  title_year  budget  Gross  profit  \
# 10                         Hugo        2011     170     73     -97
# 9             The Little Prince        2015      81      1     -80
# 8              Edge of Tomorrow        2014     178    100     -78
# 7                       Tangled        2010     260    200     -60
# 6   Scott Pilgrim vs. the World        2010      60     31     -29
# 5            X-Men: First Class        2011     160    146     -14
# 4                       Flipped        2010      14      1     -13
# 2                          Rush        2013      38     26     -12
# 3                       Warrior        2011      25     13     -12
# 1                         Amour        2012       8      0      -8
# 0       Tucker and Dale vs Evil        2010       5      0      -5
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 10  ChloÃ« Grace Moretz     Christopher Lee            Ray Winstone
# ...

# %%
movies['MetaCritic'] = movies['MetaCritic']/10

# %%
movies.insert(18, column='Avg_Rating',value=movies.loc[:,['MetaCritic', 'IMDb_rating']].mean(axis=1))

# %%
movies.sort_values(by='Avg_Rating', ascending=False, inplace=True)

# %%
movies
# Out:
#                                               Title  title_year  budget  \
# 69                                          Boyhood        2014       4
# 51                                 12 Years a Slave        2013      20
# 9                                        Inside Out        2015     175
# 20                                       La La Land        2016      30
# 49                            Manchester by the Sea        2016       9
# 4                                       Toy Story 3        2010     200
# 10                                          Gravity        2013     100
# 64                                        Spotlight        2015      20
# 80                                         Whiplash        2014       3
# 81                                  Before Midnight        2013       3
# 90                                            Amour        2012       8
# 38                               The Social Network        2010      40
# ...

# %%
UniversalAcclaim = movies[(abs(movies['MetaCritic']-movies['IMDb_rating'])<0.5) & (movies['Avg_Rating']>8)].sort_index()

# %%
UniversalAcclaim
# Out:
#                                          Title  title_year  budget  Gross  \
# 0   Star Wars: Episode VII - The Force Awakens        2015     245    936
# 36                            Django Unchained        2012     100    162
# 40                                     Arrival        2016      47    100
# 67                          Dallas Buyers Club        2013       5     27
# 80                                    Whiplash        2014       3     13
#
#     profit         actor_1_name     actor_2_name     actor_3_name  \
# 0      691          Doug Walker       Rob Walker                0
# 36      62    Leonardo DiCaprio  Christoph Waltz     Ato Essandoh
# 40      53            Amy Adams    Jeremy Renner  Forest Whitaker
# 67      22  Matthew McConaughey  Jennifer Garner     Denis O'Hare
# 80      10         J.K. Simmons  Melissa Benoist     Chris Mulkey
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
UniversalAcclaim.sort_values(by='Avg_Rating',ascending=False, inplace=True)

# %%
UniversalAcclaim
# Out:
#                                          Title  title_year  budget  Gross  \
# 80                                    Whiplash        2014       3     13
# 36                            Django Unchained        2012     100    162
# 67                          Dallas Buyers Club        2013       5     27
# 0   Star Wars: Episode VII - The Force Awakens        2015     245    936
# 40                                     Arrival        2016      47    100
#
#     profit         actor_1_name     actor_2_name     actor_3_name  \
# 80      10         J.K. Simmons  Melissa Benoist     Chris Mulkey
# 36      62    Leonardo DiCaprio  Christoph Waltz     Ato Essandoh
# 67      22  Matthew McConaughey  Jennifer Garner     Denis O'Hare
# 0      691          Doug Walker       Rob Walker                0
# 40      53            Amy Adams    Jeremy Renner  Forest Whitaker
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
UniversalAcclaim.reset_index(drop=True, inplace=True)

# %%
UniversalAcclaim
# Out:
#                                         Title  title_year  budget  Gross  \
# 0                                    Whiplash        2014       3     13
# 1                            Django Unchained        2012     100    162
# 2                          Dallas Buyers Club        2013       5     27
# 3  Star Wars: Episode VII - The Force Awakens        2015     245    936
# 4                                     Arrival        2016      47    100
#
#    profit         actor_1_name     actor_2_name     actor_3_name  \
# 0      10         J.K. Simmons  Melissa Benoist     Chris Mulkey
# 1      62    Leonardo DiCaprio  Christoph Waltz     Ato Essandoh
# 2      22  Matthew McConaughey  Jennifer Garner     Denis O'Hare
# 3     691          Doug Walker       Rob Walker                0
# 4      53            Amy Adams    Jeremy Renner  Forest Whitaker
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %% [markdown]
# ## Now, your production company is looking to make a blockbuster movie. There will primarily be three lead roles in your movie and the company wishes to cast the most popular actors for it.
#
# ## Since your manager doesn’t want to take a risk, he asked you to cast a trio that has already acted together in a movie before.
#
# ## So our next task would be-
#
# ## Find the Most Popular Trios — I

# %%
movies.insert(11, column='popularity', value=movies.loc[:,['actor_1_facebook_likes',
                                                       'actor_2_facebook_likes',
                                                       'actor_3_facebook_likes']].sum(axis=1))

# %%
top_popular_actors = movies.sort_values(by = 'popularity', ascending=False, ignore_index=True).loc[0:5,:]

# %%
top_popular_actors
# Out:
#                         Title  title_year  budget  Gross  profit  \
# 0                        Lion        2016      12     51      39
# 1                   Inception        2010     160    292     132
# 2  X-Men: Days of Future Past        2014     200    233      33
# 3       Manchester by the Sea        2016       9     47      38
# 4       The Dark Knight Rises        2012     250    448     198
# 5     Silver Linings Playbook        2012      21    132     111
#
#         actor_1_name        actor_2_name          actor_3_name  \
# 0          Dev Patel       Nicole Kidman           Rooney Mara
# 1  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 2  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 3      Casey Affleck  Michelle Williams          Kyle Chandler
# 4          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
# 5  Jennifer Lawrence      Robert De Niro        Bradley Cooper
#
# ...

# %% [markdown]
# ## Find out the top 5 popular trios, and output their names in a list

# %%
top_5_popular_actors = movies.sort_values(by = 'popularity', ascending=False, 
                                        ignore_index=True).loc[0:5,[
                                        'actor_1_name',
                                        'actor_2_name',
                                        'actor_3_name']].values.tolist()

# %%
top_5_popular_actors
# Out:
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Robert De Niro', 'Bradley Cooper']]

# %% [markdown]
# ## Let’s add a small condition to it and make sure that all three actors are popular. The condition is none of the three actors’ Facebook likes should be less than half of the other two.

# %%
indiv_popularity= movies[~(
(((movies['actor_1_facebook_likes'] < movies['actor_2_facebook_likes']/2) | 
(movies['actor_1_facebook_likes'] < movies['actor_3_facebook_likes']/2)) == True) |
(((movies['actor_2_facebook_likes'] < movies['actor_1_facebook_likes']/2) |
(movies['actor_2_facebook_likes'] < movies['actor_3_facebook_likes']/2)) == True) |
(((movies['actor_3_facebook_likes'] < movies['actor_1_facebook_likes']/2) |
(movies['actor_3_facebook_likes'] < movies['actor_2_facebook_likes']/2)) == True) 
)]

# %%
indiv_popularity
# Out:
#                          Title  title_year  budget  Gross  profit  \
# 69                     Boyhood        2014       4     25      21
# 20                  La La Land        2016      30    151     121
# 58                  The Artist        2011      15     44      29
# 27                        Argo        2012      44    136      92
# 82                    Nebraska        2013      12     17       5
# 62                   Moneyball        2011      50     75      25
# 17                   Inception        2010     160    292     132
# 5        The Dark Knight Rises        2012     250    448     198
# 24                   Gone Girl        2014      61    167     106
# 68                Interstellar        2014     165    187      22
# 79                  Ex Machina        2014      15     25      10
# 93                     Flipped        2010      14      1     -13
# 54  X-Men: Days of Future Past        2014     200    233      33
# ...

# %%
common_actors = top_popular_actors['Title'].isin(indiv_popularity['Title'])

# %%
common_actors
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: Title, dtype: bool

# %%
comon_actor=top_popular_actors[common_actors]

# %%
comon_actor.loc[:,['actor_1_name', 'actor_2_name', 'actor_3_name']].values.tolist()
# Out:
# [['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %%
top_indiv_popularity=indiv_popularity.sort_values(by='popularity', ascending=False)[0:5]

# %%
top_indiv_popularity.loc[:,['actor_1_name', 'actor_2_name', 'actor_3_name']].values.tolist()
# Out:
# [['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt'],
#  ['Chris Hemsworth', 'Robert Downey Jr.', 'Scarlett Johansson'],
#  ['Robert Downey Jr.', 'Scarlett Johansson', 'Chris Evans']]

# %%
top_indiv_popularity
# Out:
#                          Title  title_year  budget  Gross  profit  \
# 17                   Inception        2010     160    292     132
# 54  X-Men: Days of Future Past        2014     200    233      33
# 5        The Dark Knight Rises        2012     250    448     198
# 1                 The Avengers        2012     220    623     403
# 12  Captain America: Civil War        2016     250    407     157
#
#          actor_1_name        actor_2_name          actor_3_name  \
# 17  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 54  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 5           Tom Hardy      Christian Bale  Joseph Gordon-Levitt
# 1     Chris Hemsworth   Robert Downey Jr.    Scarlett Johansson
# 12  Robert Downey Jr.  Scarlett Johansson           Chris Evans
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 17                   29000                 27000.0                 23000.0
# ...

# %% [markdown]
# ## There is a column named Runtime in the dataframe which primarily shows the length of the movie. It might be interesting to see how this variable is distributed. Plot a histogram or distplot of seaborn to find the Runtime range most of the movies fall into.

# %%
plt.figure(figsize=[8,4])
run = sns.distplot(movies['Runtime'], color='blue')
run.axes.set_title("Movie Runtime Distribution", fontsize=20)
run.set_xlabel('Runtime', fontsize = 15)
run.set_ylabel('Count', fontsize = 15)
plt.show()
# Out:
# /Users/megatnorulazmimegatmohamednoor/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## R- rated movies
# ## 1. Filter out movies that are R- rated
# ## 2. Sort them by ‘CVotesU18’ in descending order
# ## 3. Get the top 5

# %%
conten_r = movies[movies['content_rating']=='R']

# %%
conten_r
# Out:
#                                               Title  title_year  budget  \
# 69                                          Boyhood        2014       4
# 51                                 12 Years a Slave        2013      20
# 49                            Manchester by the Sea        2016       9
# 64                                        Spotlight        2015      20
# 80                                         Whiplash        2014       3
# 81                                  Before Midnight        2013       3
# 84                               Mad Max: Fury Road        2015     150
# 87                                              Her        2013      23
# 52                         The Grand Budapest Hotel        2014      25
# 19                                The King's Speech        2010      15
# 65  Birdman or (The Unexpected Virtue of Ignorance)        2014      18
# 76                               Hell or High Water        2016      12
# ...

# %%
popular_r=conten_r.sort_values(by='CVotesU18', ascending=False,ignore_index=True)

# %%
popular_r[0:5]
# Out:
#                      Title  title_year  budget  Gross  profit  \
# 0                 Deadpool        2016      58    363     305
# 1  The Wolf of Wall Street        2013     100    116      16
# 2         Django Unchained        2012     100    162      62
# 3       Mad Max: Fury Road        2015     150    153       3
# 4                 Whiplash        2014       3     13      10
#
#         actor_1_name         actor_2_name    actor_3_name  \
# 0      Ryan Reynolds            Ed Skrein  Stefan Kapicic
# 1  Leonardo DiCaprio  Matthew McConaughey     Jon Favreau
# 2  Leonardo DiCaprio      Christoph Waltz    Ato Essandoh
# 3          Tom Hardy      Charlize Theron    ZoÃ« Kravitz
# 4       J.K. Simmons      Melissa Benoist    Chris Mulkey
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   16000                   805.0                   361.0
# 1                   29000                 11000.0                  4000.0
# ...

# %% [markdown]
# ## Demographic analysis
#
# There are 3 columns in the dataframe — genre_1, genre_2, and genre_3. As a part of this analysis, we need to aggregate a few values over these 3 columns.
#
# - First, create a new dataframe df_by_genre that contains genre_1, genre_2, and genre_3 and all the columns related to CVotes/Votes from the movies data frame. There are 47 columns to be extracted in total.
# - Now, add a column called cnt to the dataframe df_by_genre and initialize it to one. We will realize the use of this column by the end of this analysis
# - Group the dataframe df_by_genre by genre_1 and find the sum of all the numeric columns such as cnt, columns related to CVotes and Votes columns and store it in a dataframe df_by_g1
# - Performing the same operation for genre_2 and genre_3 and store it dataframes df_by_g2 and df_by_g3 respectively

# %%
column_list=[]
 
for i in movies.columns:
    if i.startswith('CV')  | i.startswith('V') | i.startswith('ge'):
        column_list.append(i)
        
df_by_genre = movies.loc[:, column_list]

# %%
df_by_genre
# Out:
#       genre_1    genre_2    genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 69      Drama        NaN        NaN     49673     62055     76838     52238
# 51  Biography      Drama    History     75556    126223    161460     83070
# 9   Animation  Adventure     Comedy     87509    113244    119801     67153
# 20     Comedy      Drama      Music     74245     71191     64640     38831
# 49      Drama        NaN        NaN     18191     33532     46596     29626
# 4   Animation  Adventure     Comedy    139773    149992    158704     88289
# 10      Drama     Sci-Fi   Thriller     89986    127616    169693    122275
# 64      Crime      Drama    History     35421     72285    100793     49236
# 80      Drama      Music        NaN    110404    161864    132656     56007
# 81      Drama    Romance        NaN     16953     22109     31439     19251
# 90      Drama    Romance        NaN     11093     15944     22942     14187
# ...

# %%
df_by_genre ['cnt'] = 1

# %%
df_by_g1 = df_by_genre.groupby('genre_1')
df_by_g2 = df_by_genre.groupby('genre_2')
df_by_g3 = df_by_genre.groupby('genre_3')

# %%
df_by_genre.groupby('genre_1').apply(print)
# Out:
#    genre_1    genre_2   genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 84  Action  Adventure    Sci-Fi    136194    158403    163494     97218
# 27  Action  Biography     Drama     43875     89490    171495    115165
# 17  Action  Adventure    Sci-Fi    584839    485218    304457    130972
# 0   Action  Adventure   Fantasy    155391    161810    166378     99402
# 5   Action   Thriller       NaN    380589    341965    281426    134959
# 25  Action  Adventure  Thriller     69286    105160    178610    119630
# 74  Action      Crime     Drama     19576     40247     85359     64633
# 34  Action  Biography     Drama     27835     55315    117623     64849
# 11  Action  Adventure    Sci-Fi    156606    185326    216876    127878
# 91  Action  Biography     Drama     53667     90907    119603     57343
# 50  Action  Adventure     Drama     37605     58021    112652     84789
# 54  Action  Adventure    Sci-Fi     91765    127521    183578    104658
# ...

# %%
df_by_g1= pd.DataFrame(df_by_g1.sum()) #df_by_g1= df_by_g1.sum() same result
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# genre_1
# Action       156150     89483     61975    162426     9994618       1858890
# Adventure     58559     33174     22018     48100     3535070        802902
# Animation     30718     15733     10026     25193     2282985        724844
# ...

# %%
df_by_g2= pd.DataFrame(df_by_g2.sum()) #df_by_g1= df_by_g1.sum() same result
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
df_by_g3= pd.DataFrame(df_by_g3.sum()) #df_by_g1= df_by_g1.sum() same result
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# ...

# %%
add_df1_df2 = df_by_g1.add(df_by_g2, fill_value=0)
df_add = add_df1_df2.add(df_by_g3, fill_value=0)

# %%
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
genre_top10 = df_add[df_add['cnt'] >= 10]
genre_top10.head(20)
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# ...

# %%
count_column = genre_top10 ['cnt']

# %%
count_column
# Out:
# Action       31.0
# Adventure    38.0
# Animation    11.0
# Biography    18.0
# Comedy       23.0
# Crime        11.0
# Drama        65.0
# Romance      13.0
# Sci-Fi       17.0
# Thriller     13.0
# Name: cnt, dtype: float64

# %%
genre_top10 = genre_top10.div(genre_top10['cnt'], axis=0)

# %%
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
genre_top10=genre_top10.apply(lambda x: round(x,2), axis =0)
genre_top10.drop(columns='cnt', inplace=True)

# %%
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07  CVotes06  CVotes05  \
# Action     102144.10  114433.19  150895.32   94262.13  34688.84  12693.03
# Adventure   94596.29  105636.63  138482.32   86367.92  31896.71  11551.84
# Animation   61960.18   72566.09  104837.64   65707.45  22825.09   7551.73
# Biography   47333.50   77867.11  123948.78   74054.44  23644.17   7702.67
# Comedy      60157.22   77173.35  108993.52   69176.91  26099.43   9863.13
# Crime       52229.64   87919.82  129045.00   74671.82  25308.27   8971.82
# Drama       52375.97   75928.85  109339.28   66456.92  23528.55   8497.11
# Romance     42304.54   53037.85   82252.31   54833.92  21637.62   8530.85
# Sci-Fi     136781.41  148873.82  176646.71  106005.76  39518.29  14951.47
# Thriller    83207.77  112730.08  153336.77   90446.08  32003.54  11534.85
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action      5386.13   3064.65   2115.26   5524.10   349581.74      67916.45
# ...

# %%
#converting cvotes to int type
col_cvotes_list=[]
for i in genre_top10.columns:
    if i.startswith('CVotes'):
        col_cvotes_list.append(i)

# %%
genre_top10[col_cvotes_list]=genre_top10[col_cvotes_list].astype('int')
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action         5386      3064      2115      5524      349581         67916
# ...

# %% [markdown]
# ## We will now make a bar chart plotting different genres vs cnt using seaborn and derive some insights from this data frame

# %%
cnt=count_column.tolist()
genre_top10['cnt']=cnt
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action         5386      3064      2115      5524      349581         67916
# ...

# %%
plt.figure(figsize=[8,4])
sns.barplot(x=genre_top10.index, y=genre_top10.cnt, color='blue')
plt.title('Different Genre with Count', fontsize=20)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## If you have closely looked at the Votes- and CVotes-related columns, you might have noticed the suffixes F and M indicating Female and Male. Since we have the vote counts for both males and females, across various age groups, let's now see how the popularity of genres vary between the two genders in the dataframe

# %%
# 1st set of heat maps for CVotes-related columns
male_cvote_genre= genre_top10.groupby (genre_top10.index) ['CVotesU18M' , 'CVotes1829M','CVotes3044M', 'CVotes45AM' ].mean()
female_cvote_genre= genre_top10.groupby (genre_top10.index) ['CVotesU18F', 'CVotes1829F', 'CVotes3044F' , 'CVotes45AF'].mean()
f, (ax1,ax2, axcb) = plt.subplots (1,3, gridspec_kw={'width_ratios': [1,1, 0.08]})
ax1.get_shared_y_axes().join(ax1,ax2)

g1 = sns.heatmap (male_cvote_genre, cmap="Greens", annot= True, fmt='f', cbar=False, ax=ax1)
g1.set_ylabel ('Genres', fontsize= 10)
g1.set_xlabel ('Male Age group', fontsize= 10)
g2 = sns.heatmap (female_cvote_genre, cmap="Greens", annot= True, fmt='f', cbar_ax=axcb,ax=ax2)
g2.set_ylabel('')
g2.set_xlabel('Female Age group', fontsize= 10)
g2.set_yticks([])

# mav be needed to rotate the ticklabels correctly:
for ax in [g1, g2]:
    t1 = ax.get_xticklabels()
    ax.set_xticklabels(t1, rotation=90)
    tly = ax.get_yticklabels()
    ax.set_yticklabels(tly, rotation=0)
    
plt.show()
plt.tight_layout()
# Out:
# /var/folders/fk/qqmpzjpx065dy68cqvfyftrm0000gn/T/ipykernel_2535/978269173.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   male_cvote_genre= genre_top10.groupby (genre_top10.index) ['CVotesU18M' , 'CVotes1829M','CVotes3044M', 'CVotes45AM' ].mean()
# /var/folders/fk/qqmpzjpx065dy68cqvfyftrm0000gn/T/ipykernel_2535/978269173.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   female_cvote_genre= genre_top10.groupby (genre_top10.index) ['CVotesU18F', 'CVotes1829F', 'CVotes3044F' , 'CVotes45AF'].mean()

# %% [markdown]
# ## Inferences: A few inferences that can be seen from the heatmap above is that males have voted more than females, and Sci-Fi appears to be most popular among the 18–29 age group irrespective of their gender. What more can we infer from the two heatmaps that are plotted?

# %%
# 2nd set of heat maps for Votes-related coLumns
male_vote_genre= genre_top10.groupby(genre_top10.index) ['VotesU18M','Votes1829M','Votes3044M','Votes45AM'].mean()
female_vote_genre= genre_top10.groupby(genre_top10.index) ['VotesU18F','Votes1829F','Votes3044F','Votes45AF'].mean()
                                                            
f, (ax1,ax2, axcb) = plt.subplots(1,3, gridspec_kw={'width_ratios': [1,1, 0.08]})
ax1.get_shared_y_axes().join(ax1,ax2)
                                                            
g1 = sns.heatmap (male_vote_genre, cmap="coolwarm", annot= True, cbar= False, ax=ax1)
g1.set_ylabel ('Genres', fontsize= 10)
g1.set_xlabel ('Male Age group', fontsize= 10)
g2 = sns.heatmap(female_vote_genre, cmap="coolwarm", annot= True, cbar_ax= axcb,ax=ax2)
g2.set_ylabel(" ")
g2.set_xlabel ('Female Age group', fontsize= 10)
g2.set_yticks ([])
# mav be needed to rotate the ticklabels correctly:
for ax in [g1, g2]:
    tl = ax.get_xticklabels()
    ax.set_xticklabels(t1, rotation=90)
    tly = ax.get_yticklabels()
    ax.set_yticklabels(tly, rotation=0)
               
plt.show()
plt.tight_layout()
# Out:
# /var/folders/fk/qqmpzjpx065dy68cqvfyftrm0000gn/T/ipykernel_2535/2772273635.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   male_vote_genre= genre_top10.groupby(genre_top10.index) ['VotesU18M','Votes1829M','Votes3044M','Votes45AM'].mean()
# /var/folders/fk/qqmpzjpx065dy68cqvfyftrm0000gn/T/ipykernel_2535/2772273635.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   female_vote_genre= genre_top10.groupby(genre_top10.index) ['VotesU18F','Votes1829F','Votes3044F','Votes45AF'].mean()

# %% [markdown]
# ## The USA vs non-USA cross-analysis
# ## Note: Use the movies dataframe for this subtask. Make use of this documentation to format your boxplot - boxplot

# %%
# Creating IFUS coLumn
movies [ 'IFUS'] = movies['Country'].apply(lambda x: 'USA' if x=="USA" else "non-USA")

# %%
# Box plot - 1: CVotesUS(V) us IFUS(x)
plt.figure(figsize=[10,10])
fig, axes =plt. subplots (nrows=1, ncols=2)
b1= sns.boxplot (x= 'IFUS', y='CVotesUS', data= movies, orient='v', ax= axes[0], color='blue')
b1.axes.set_title('Dist. of votes from USA People', fontsize= 10)
b1.set_ylabel ('CVotesUS', fontsize= 10)
b1.set_xlabel('IFUS', fontsize= 10)
b2= sns.boxplot (x= 'IFUS', y= 'CVotesnUS', data= movies, orient='v', ax= axes[1], color= 'red')
b2.axes.set_title( 'Dist. of votes from non-USA People', fontsize= 10)
b2.set_ylabel ('VotesnUS', fontsize= 10)
b2.set_xlabel('IFUS',fontsize= 10)
plt.tight_layout()
## for non-overlapping Labels

# %% [markdown]
# ## Again we’ll do a similar analysis but with the ratings. Make a boxplot that shows how the ratings from the US people i.e. VotesUS is varying for the US and non-US movies. Similarly, make another subplot that shows how VotesnUS is varying for the US and non-US movies.

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)
plt.figure(figsize=[10,10])
fig, axes = plt.subplots (nrows=1, ncols=2)
b3=sns.boxplot(x="IFUS", y='VotesUS', data= movies, orient='v', ax= axes[0], color='blue')
b3.axes.set_title( 'Dist. of rating from USA People', fontsize= 10)
b3.set_ylabel( 'VotesUS', fontsize= 10)
b3.set_xlabel('IFUS', fontsize= 10)
b4= sns.boxplot (x= 'IFUS', y= 'VotesnUS', data= movies, orient= 'v', ax= axes[1], color= 'red')
b4.axes.set_title( 'Dist. of rating from non-USA People', fontsize= 10)
b4.set_ylabel ('VotesnUS', fontsize= 10)
b4.set_xlabel ('IFUS', fontsize= 10)
plt.tight_layout()
## for non-overLapping Labels

# %% [markdown]
# ## You might have also observed the column CVotes1000. This column represents the top 1000 voters on IMDb and gives the count for the number of these voters who have voted for a particular movie. Let's see how these top 1000 voters have voted across the genres.

# %%
# Sorting by CVotes1000
genre_top10_Cvotes= genre_top10.sort_values(by='CVotes1000', ascending= False)

# %%
# Bar pLot
plt.figure(figsize=[8,4])
sns.barplot(x= genre_top10_Cvotes.index, y= genre_top10_Cvotes.CVotes1000, color= 'blue')
plt.title( 'Top 1000 Voters Vs Genres',fontsize= 20)
plt.xlabel ('Movie genre', fontsize= 15)
plt.ylabel ('CVotes1000', fontsize= 15)
# Out:
# Text(0, 0.5, 'CVotes1000')
